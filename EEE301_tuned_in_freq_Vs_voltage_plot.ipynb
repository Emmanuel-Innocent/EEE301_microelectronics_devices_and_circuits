# %%
#*********           Innocent Emmanuel Godswill         *****************
#*********               EEG/2017/059                   *****************
#*********             EEE301 Assignment                *****************
#*********             12 March, 2021.                  *****************

import math
from matplotlib import pyplot as plt
# %matplotlib notebook
import numpy as np
#**********************************************************************************************************
#          This code plots range of frequency that can be tuned in                                        *
#          against bias voltage across a pn juction capacitor.                                            *          
#          The maximum bias voltage corresponds to the maximum E-field allowable in the junction.         *
#**********************************************************************************************************
#************                  The parameters are thus defined:                    ************************

# The junction capacitance at thermal equilibrium  (F/cm square)
Cjo = 3.715*(10**-9)    

#Built-in potential at thermal equilibrium  (V)
Phi_B = 0.6

#Junction area (cm square)
A = 1.364*(10**-3)

#inductance  (Henry)
L = 5*(10**-9)

#range for the bias voltage  (v)
V_D = np.arange(-158,0, 1)  

#list for corresponding tuned-in frequecies  (Hertz)
f = [(((1- v/Phi_B)**1.0/4.0)/(2*math.pi*math.sqrt(L*Cjo*A))) for v in V_D]

#plot graph
plt.plot(x,f)
plt.show()
plt.xlabel('voltage(V)')
plt.ylabel('frequency(Hz)')
plt.title('tuned-in frequency vs bias voltage')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'tuned-in frequency vs bias voltage')
